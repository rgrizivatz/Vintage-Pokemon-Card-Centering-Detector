# %% [markdown]
# # Yellow Frame Detector – Example Notebook
# This notebook demonstrates how to use `yellow_cardframe_detector.py` together with `config.yaml` to analyze a Pokémon card border.

# %%
from yellow_cardframe_detector import run_pipeline
import matplotlib.pyplot as plt

# Path to your card image
IMAGE_PATH = 'images/ditto.webp'   # Update if needed
CONFIG_PATH = 'config.yaml'

results = run_pipeline(IMAGE_PATH, CONFIG_PATH)
results
# Out:
# {'centering_LR': 0.4588235294117647,
#  'centering_TB': 0.46808510638297873,
#  'quartiles': {'left': [38.0, 39.0, 39.0],
#   'right': [44.0, 46.0, 48.0],
#   'top': [42.0, 44.0, 45.0],
#   'bottom': [48.0, 50.0, 52.0]}}
